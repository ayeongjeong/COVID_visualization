# %% [markdown]
# # KT 코로나 시각화 경진대회 - 대구와 서울을 중심으로 데이터 비교

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt 
import seaborn as sns

# %%
from matplotlib import font_manager, rc
# window >
# font_name = font_manager.FontProperties(fname="/Windows/Fonts/NanumGothicCoding.ttf").get_name()
# gram >
# font_name = font_manager.FontProperties(fname="/Windows/Fonts/gulim.ttc").get_name()
# rc('font', family=font_name)
# linux >
font_name = font_manager.FontProperties(fname="/home/sundooedu/.local/share/fonts/NanumGothicCoding.ttf").get_name()

# %% [markdown]
# ## 데이터 불러오기

# %%
# COVID DATA
patientinfo=pd.read_csv('./KTdata/COVID_19/PatientInfo_20200717.csv')
case=pd.read_csv('./KTdata/COVID_19/Case.csv')
policy=pd.read_csv('./KTdata/COVID_19/Policy.csv')
region=pd.read_csv('./KTdata/COVID_19/Region.csv')
time=pd.read_csv('./KTdata/COVID_19/Time.csv')
timeage=pd.read_csv('./KTdata/COVID_19/TimeAge.csv')
timegender=pd.read_csv('./KTdata/COVID_19/TimeGender.csv')
timeprovince=pd.read_csv('./KTdata/COVID_19/TimeProvince.csv')
# KT DATA
fpopl=pd.read_csv('./KTdata/fpopl.csv')
adstrd=pd.read_csv('./KTdata/adstrd_master.csv')
card=pd.read_csv('./KTdata/card.csv')
delivery=pd.read_csv('./KTdata/delivery.csv')
index=pd.read_csv('./KTdata/index.csv')

# %% [markdown]
# ## 파일별로 데이터 확인하고 시각화 해보기

# %% [markdown]
# 1. COVID_Data1 - PatientInfo

# %%
patientinfo
# Out:
#       patient_id     sex  age     country province city        infection_case  \
# 0     1000000001    male  50s       Korea       서울  강서구       overseas inflow
# 1     1000000002    male  30s       Korea       서울  중랑구       overseas inflow
# 2     1000000003    male  50s       Korea       서울  종로구  contact with patient
# 3     1000000004    male  20s       Korea       서울  마포구       overseas inflow
# 4     1000000005  female  20s       Korea       서울  성북구  contact with patient
# ...          ...     ...  ...         ...      ...  ...                   ...
# 5159  7000000015  female  30s       Korea      제주도  제주도       overseas inflow
# 5160  7000000016     NaN  NaN       Korea      제주도  제주도       overseas inflow
# 5161  7000000017     NaN  NaN  Bangladesh      제주도  제주도       overseas inflow
# 5162  7000000018     NaN  NaN  Bangladesh      제주도  제주도       overseas inflow
# 5163  7000000019     NaN  NaN  Bangladesh      제주도  제주도       overseas inflow
#
#      infected_by  contact_number symptom_onset_date confirmed_date  \
# 0            NaN            75.0         2020-01-22     2020-01-23
# 1            NaN            31.0                NaN     2020-01-30
# 2     2002000001            17.0                NaN     2020-01-30
# 3            NaN             9.0         2020-01-26     2020-01-30
# 4     1000000002             2.0                NaN     2020-01-31
# ...          ...             ...                ...            ...
# 5159         NaN            25.0                NaN     2020-05-30
# 5160         NaN             NaN                NaN     2020-06-16
# 5161         NaN            72.0                NaN     2020-06-18
# 5162         NaN             NaN                NaN     2020-06-18
# 5163         NaN             NaN                NaN     2020-06-18
#
#      released_date deceased_date     state
# 0       2020-02-05           NaN  released
# 1       2020-03-02           NaN  released
# 2       2020-02-19           NaN  released
# 3       2020-02-15           NaN  released
# 4       2020-02-24           NaN  released
# ...            ...           ...       ...
# 5159    2020-06-13           NaN  released
# 5160    2020-06-24           NaN  released
# 5161           NaN           NaN  isolated
# 5162           NaN           NaN  isolated
# 5163           NaN           NaN  isolated
#
# [5164 rows x 14 columns]

# %%
patientinfo.infection_case.value_counts()
# Out:
# contact with patient                             1610
# overseas inflow                                   839
# etc                                               703
# Itaewon Clubs                                     162
# Richway                                           128
# Guro-gu Call Center                               112
# Shincheonji Church                                107
# Coupang Logistics Center                           80
# Yangcheon Table Tennis Club                        44
# Day Care Center                                    43
# SMR Newly Planted Churches Group                   36
# Onchun Church                                      33
# Bonghwa Pureun Nursing Home                        31
# gym facility in Cheonan                            30
# Ministry of Oceans and Fisheries                   28
# Wangsung Church                                    24
# Cheongdo Daenam Hospital                           21
# Dongan Church                                      17
# Eunpyeong St. Mary's Hospital                      16
# Gyeongsan Seorin Nursing Home                      15
# KB Life Insurance                                  13
# Dunsan Electronics Town                            13
# Seongdong-gu APT                                   13
# Gyeongsan Jeil Silver Town                         12
# Milal Shelter                                      11
# Gyeongsan Cham Joeun Community Center              10
# Korea Campus Crusade of Christ                      7
# Samsung Medical Center                              7
# Orange Town                                         7
# Geumcheon-gu rice milling machine manufacture       6
# Gangnam Yeoksam-dong gathering                      6
# Geochang Church                                     6
# Guri Collective Infection                           5
# Seocho Family                                       5
# Yeonana News Class                                  5
# Yongin Brothers                                     4
# gym facility in Sejong                              4
# Samsung Fire & Marine Insurance                     4
# Changnyeong Coin Karaoke                            4
# Seoul City Hall Station safety worker               3
# Daezayeon Korea                                     3
# Suyeong-gu Kindergarten                             3
# Yeongdeungpo Learning Institute                     3
# Biblical Language study meeting                     3
# Pilgrimage to Israel                                2
# Uiwang Logistics Center                             2
# River of Grace Community Church                     1
# Daejeon door-to-door sales                          1
# Anyang Gunpo Pastors Group                          1
# Orange Life                                         1
# Gangnam Dongin Church                               1
# Name: infection_case, dtype: int64

# %% [markdown]
# infection_case에 신천지교회 수가 맞지 않음. 데이터 양도 적고 정확하지 않으므로 사용할 필요 없어 보임

# %% [markdown]
# 2. COVID_Data1 - Case

# %%
case
# Out:
#       case_id province city  group               infection_case  confirmed  \
# 0     1000001       서울  용산구   True                Itaewon Clubs        139
# 1     1000002       서울  관악구   True                      Richway        119
# 2     1000003       서울  구로구   True          Guro-gu Call Center         95
# 3     1000004       서울  양천구   True  Yangcheon Table Tennis Club         43
# 4     1000005       서울  도봉구   True              Day Care Center         43
# ..        ...      ...  ...    ...                          ...        ...
# 169   6100012     경상남도    -  False                          etc         20
# 170   7000001      제주도    -  False              overseas inflow         14
# 171   7000002      제주도    -  False         contact with patient          0
# 172   7000003      제주도    -  False                          etc          4
# 173   7000004      제주도  타도시   True                Itaewon Clubs          1
#
#       latitude   longitude
# 0    37.538621  126.992652
# 1     37.48208  126.901384
# 2    37.508163  126.884387
# 3    37.546061  126.874209
# 4    37.679422  127.044374
# ..         ...         ...
# 169          -           -
# 170          -           -
# 171          -           -
# 172          -           -
# 173          -           -
#
# [174 rows x 8 columns]

# %%
case_sd = case[(case['province']=='대구') | (case['province']=='서울')]

# %%
plt.figure(figsize = (20,10))
sns.barplot(data = case_sd, x = 'infection_case', y = 'confirmed', hue='province', palette="deep")
plt.xticks(rotation=45, horizontalalignment='right')
plt.yscale('log')

# %% [markdown]
# 3. COVID_Data1 - Policy

# %%
policy
# Out:
#     policy_id country            type                              gov_policy  \
# 0           1   Korea           Alert          Infectious Disease Alert Level
# 1           2   Korea           Alert          Infectious Disease Alert Level
# 2           3   Korea           Alert          Infectious Disease Alert Level
# 3           4   Korea           Alert          Infectious Disease Alert Level
# 4           5   Korea     Immigration           Special Immigration Procedure
# ..        ...     ...             ...                                     ...
# 56         57   Korea  Transformation                        Logistics center
# 57         58   Korea  Transformation                        Wearing of masks
# 58         59   Korea  Transformation                        Wearing of masks
# 59         60   Korea      Technology          KI-Pass: Korea Internet - Pass
# 60         61   Korea          Health  Extends Tightened Quarantine Measures
#
#                                                detail  start_date    end_date
# 0                                      Level 1 (Blue)  2020-01-03  2020-01-19
# 1                                    Level 2 (Yellow)  2020-01-20  2020-01-27
# 2                                    Level 3 (Orange)  2020-01-28  2020-02-22
# 3                                       Level 4 (Red)  2020-02-23         NaN
# 4                                          from China  2020-02-04         NaN
# ..                                                ...         ...         ...
# 56  On-site inspection of major logistics faciliti...  2020-05-29  2020-06-11
# 57  Mandatory wearing of passenger mask domestic, ...  2020-05-27         NaN
# 58  Drivers such as buses and taxis can refuse to ...  2020-05-26         NaN
# 59  new quick response (QR) code system this week ...  2020-06-10         NaN
# 60  Gov't Extends Tightened Quarantine Measures in...  2020-05-28  2020-06-14
#
# [61 rows x 7 columns]

# %%
policy.gov_policy.value_counts()
# Out:
# Special Immigration Procedure                    13
# School Opening with Online Class                 10
# Emergency Use Authorization of Diagnostic Kit     5
# Infectious Disease Alert Level                    4
# School Opening Delay                              4
# Social Distancing Campaign                        4
# Mask Distribution                                 2
# Drive-Through Screening Center                    2
# Wearing of masks                                  2
# Logistics center                                  1
# Mandatory 14-day Self-Quarantine                  1
# Self-Diagnosis App                                1
# Open Data                                         1
# Close karaoke                                     1
# Extends Tightened Quarantine Measures             1
# School Closure                                    1
# Electronic Wristbands                             1
# KI-Pass: Korea Internet - Pass                    1
# local government Administrative orders            1
# Mandatory Self-Quarantine & Diagonostic Tests     1
# Self-Quarantine Safety Protection App             1
# Close bars and clubs                              1
# Thanks to Challenge korea                         1
# Open API                                          1
# Name: gov_policy, dtype: int64

# %% [markdown]
# 정책관련 데이터는 사용할 필요 없을 것 같음

# %% [markdown]
# 4. COVID_Data1 - Region

# %%
region
# Out:
#       code province  city   latitude   longitude  elementary_school_count  \
# 0    10000       서울    서울  37.566953  126.977977                      607
# 1    10010       서울   강남구  37.518421  127.047222                       33
# 2    10020       서울   강동구  37.530492  127.123837                       27
# 3    10030       서울   강북구  37.639938  127.025508                       14
# 4    10040       서울   강서구  37.551166  126.849506                       36
# ..     ...      ...   ...        ...         ...                      ...
# 239  61160     경상남도    하만  35.272481  128.406540                       16
# 240  61170     경상남도    함양  35.520541  127.725177                       13
# 241  61180     경상남도    합천  35.566702  128.165870                       17
# 242  70000      제주도   제주도  33.488936  126.500423                      113
# 243  80000     대한민국  대한민국  37.566953  126.977977                     6087
#
#      kindergarten_count  university_count  academy_ratio  \
# 0                   830                48           1.44
# 1                    38                 0           4.18
# 2                    32                 0           1.54
# 3                    21                 0           0.67
# 4                    56                 1           1.17
# ..                  ...               ...            ...
# 239                  20                 0           1.19
# 240                  12                 0           1.01
# 241                  15                 0           0.71
# 242                 123                 4           1.53
# 243                8837               340           1.56
#
#      elderly_population_ratio  elderly_alone_ratio  nursing_home_count
# 0                       15.38                  5.8               22739
# 1                       13.17                  4.3                3088
# 2                       14.55                  5.4                1023
# 3                       19.49                  8.5                 628
# 4                       14.39                  5.7                1080
# ..                        ...                  ...                 ...
# 239                     23.74                 14.7                  94
# 240                     32.65                 20.9                  83
# 241                     38.44                 24.7                  96
# 242                     15.10                  6.4                1245
# 243                     15.67                  7.2               94865
#
# [244 rows x 12 columns]

# %%
region_sd = region[(region['city']=='대구') | (region['city']=='서울')]
region_sd
# Out:
#      code province city   latitude   longitude  elementary_school_count  \
# 0   10000       서울   서울  37.566953  126.977977                      607
# 43  12000       대구   대구  35.872150  128.601783                      229
#
#     kindergarten_count  university_count  academy_ratio  \
# 0                  830                48           1.44
# 43                 355                11           1.62
#
#     elderly_population_ratio  elderly_alone_ratio  nursing_home_count
# 0                      15.38                  5.8               22739
# 43                     15.78                  7.5                5083

# %% [markdown]
# 경도 위도 사용하여 지도 그래프로 시각화 하면 좋을 것 같음

# %% [markdown]
# 5. COVID_Data1 - Time

# %%
time
# Out:
#            date  time     test  negative  confirmed  released  deceased
# 0    2020-01-20    16        1         0          1         0         0
# 1    2020-01-21    16        1         0          1         0         0
# 2    2020-01-22    16        4         3          1         0         0
# 3    2020-01-23    16       22        21          1         0         0
# 4    2020-01-24    16       27        25          2         0         0
# ..          ...   ...      ...       ...        ...       ...       ...
# 158  2020-06-26     0  1232315   1200885      12602     11172       282
# 159  2020-06-27     0  1243780   1211261      12653     11317       282
# 160  2020-06-28     0  1251695   1219975      12715     11364       282
# 161  2020-06-29     0  1259954   1228698      12757     11429       282
# 162  2020-06-30     0  1273766   1240157      12800     11537       282
#
# [163 rows x 7 columns]

# %%
plt.figure(figsize = (20,10))
sns.lineplot(data = time, x = 'date', y = 'test')
sns.lineplot(data = time, x = 'date', y = 'negative')

# %% [markdown]
# 지역별 비교가 아니기 때문에 사용할 필요 없을 것 같음

# %% [markdown]
# 6. COVID_Data1 - Time age & gender

# %%
timeage
# Out:
#             date  time  age  confirmed  deceased
# 0     2020-03-02     0   0s         32         0
# 1     2020-03-02     0  10s        169         0
# 2     2020-03-02     0  20s       1235         0
# 3     2020-03-02     0  30s        506         1
# 4     2020-03-02     0  40s        633         1
# ...          ...   ...  ...        ...       ...
# 1084  2020-06-30     0  40s       1681         3
# 1085  2020-06-30     0  50s       2286        15
# 1086  2020-06-30     0  60s       1668        41
# 1087  2020-06-30     0  70s        850        82
# 1088  2020-06-30     0  80s        556       139
#
# [1089 rows x 5 columns]

# %%
timegender
# Out:
#            date  time     sex  confirmed  deceased
# 0    2020-03-02     0    male       1591        13
# 1    2020-03-02     0  female       2621         9
# 2    2020-03-03     0    male       1810        16
# 3    2020-03-03     0  female       3002        12
# 4    2020-03-04     0    male       1996        20
# ..          ...   ...     ...        ...       ...
# 237  2020-06-28     0  female       7265       131
# 238  2020-06-29     0    male       5470       151
# 239  2020-06-29     0  female       7287       131
# 240  2020-06-30     0    male       5495       151
# 241  2020-06-30     0  female       7305       131
#
# [242 rows x 5 columns]

# %% [markdown]
# 나이와 성별 데이터는 지역별로 구분된 것이 아니기 때문에 사용할 필요 없을 것 같음

# %% [markdown]
# 7. COVID_Data1 - Timeprovince

# %%
timeprovince
# Out:
#             date  time province  confirmed  released  deceased
# 0     2020-01-20    16       서울          0         0         0
# 1     2020-01-20    16       부산          0         0         0
# 2     2020-01-20    16       대구          0         0         0
# 3     2020-01-20    16       인천          1         0         0
# 4     2020-01-20    16       광주          0         0         0
# ...          ...   ...      ...        ...       ...       ...
# 2766  2020-06-30     0     전라북도         27        21         0
# 2767  2020-06-30     0     전라남도         24        19         0
# 2768  2020-06-30     0     경상북도       1389      1328        54
# 2769  2020-06-30     0     경상남도        134       128         0
# 2770  2020-06-30     0      제주도         19        16         0
#
# [2771 rows x 6 columns]

# %%
timeprov_sd = timeprovince[(timeprovince['province']=='대구') | (timeprovince['province']=='서울')]

# %%
# date에서 month만 추출
def grap_month(data):
    data = str(data)
    return str(data[6:7])+'월'

timeprov_sd['month'] = timeprov_sd['date'].apply(lambda x: grap_month(x))
# Out:
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
timeprov_sd
# Out:
#             date  time province  confirmed  released  deceased month
# 0     2020-01-20    16       서울          0         0         0    1월
# 2     2020-01-20    16       대구          0         0         0    1월
# 17    2020-01-21    16       서울          0         0         0    1월
# 19    2020-01-21    16       대구          0         0         0    1월
# 34    2020-01-22    16       서울          0         0         0    1월
# ...          ...   ...      ...        ...       ...       ...   ...
# 2722  2020-06-28     0       대구       6904      6700       189    6월
# 2737  2020-06-29     0       서울       1305       942         7    6월
# 2739  2020-06-29     0       대구       6906      6700       189    6월
# 2754  2020-06-30     0       서울       1312       985         7    6월
# 2756  2020-06-30     0       대구       6906      6700       189    6월
#
# [326 rows x 7 columns]

# %%
plt.figure(figsize = (20,10))
sns.lineplot(data = timeprov_sd, x ='month', y ='confirmed', hue='province', palette="deep")

# %% [markdown]
# 대구 신천지 확진자 발생으로 2월 이후 확진자 수가 급증한 것으로 보임\
# 서울은 비교적 완만한 증가 추세를 보인다.

# %% [markdown]
# ---

# %% [markdown]
# 8. COVID_Data2 - adstrd 행정동 코드 확인

# %%
adstrd.adstrd_code = adstrd.adstrd_code.astype(int)
adstrd
# Out:
#       adstrd_code adstrd_nm  brtc_nm signgu_nm
# 0        11110515     청운효자동    서울특별시       종로구
# 1        11110530       사직동    서울특별시       종로구
# 2        11110540       삼청동    서울특별시       종로구
# 3        11110550       부암동    서울특별시       종로구
# 4        11110560       평창동    서울특별시       종로구
# ...           ...       ...      ...       ...
# 3488     50130580       서홍동  제주특별자치도      서귀포시
# 3489     50130590       대륜동  제주특별자치도      서귀포시
# 3490     50130600       대천동  제주특별자치도      서귀포시
# 3491     50130610       중문동  제주특별자치도      서귀포시
# 3492     50130620       예래동  제주특별자치도      서귀포시
#
# [3493 rows x 4 columns]

# %%
seoul = adstrd[adstrd['brtc_nm']=='서울특별시']
seoul
# Out:
#      adstrd_code adstrd_nm brtc_nm signgu_nm
# 0       11110515     청운효자동   서울특별시       종로구
# 1       11110530       사직동   서울특별시       종로구
# 2       11110540       삼청동   서울특별시       종로구
# 3       11110550       부암동   서울특별시       종로구
# 4       11110560       평창동   서울특별시       종로구
# ..           ...       ...     ...       ...
# 420     11740650      성내2동   서울특별시       강동구
# 421     11740660      성내3동   서울특별시       강동구
# 422     11740685        길동   서울특별시       강동구
# 423     11740690      둔촌1동   서울특별시       강동구
# 424     11740700      둔촌2동   서울특별시       강동구
#
# [425 rows x 4 columns]

# %%
daegu = adstrd[adstrd['brtc_nm']=='대구광역시']
daegu
# Out:
#      adstrd_code adstrd_nm brtc_nm signgu_nm
# 630     27110517       동인동   대구광역시        중구
# 631     27110545       삼덕동   대구광역시        중구
# 632     27110565      성내1동   대구광역시        중구
# 633     27110575      성내2동   대구광역시        중구
# 634     27110585      성내3동   대구광역시        중구
# ..           ...       ...     ...       ...
# 764     27710262       옥포읍   대구광역시       달성군
# 765     27710265       현풍읍   대구광역시       달성군
# 766     27710310       가창면   대구광역시       달성군
# 767     27710330       하빈면   대구광역시       달성군
# 768     27710380       구지면   대구광역시       달성군
#
# [139 rows x 4 columns]

# %%
daegu.adstrd_code.tolist()
# Out:
# [27110517,
#  27110545,
#  27110565,
#  27110575,
#  27110585,
#  27110595,
#  27110640,
#  27110650,
#  27110660,
#  27110670,
#  27110680,
#  27110690,
#  27140510,
#  27140520,
#  27140530,
#  27140540,
#  27140541,
#  27140555,
#  27140570,
#  27140580,
#  27140590,
#  27140600,
#  27140615,
#  27140620,
#  27140640,
#  27140655,
#  27140670,
#  27140685,
#  27140720,
#  27140730,
#  27140745,
#  27140760,
#  27170510,
#  27170525,
#  27170540,
#  27170550,
#  27170565,
#  27170580,
#  27170590,
#  27170600,
#  27170610,
#  27170620,
#  27170630,
#  27170640,
#  27170650,
#  27170660,
#  27170661,
#  27170675,
#  27170695,
#  27200515,
#  27200530,
#  27200540,
#  27200550,
#  27200560,
#  27200571,
#  27200586,
#  27200590,
#  27200600,
#  27200610,
#  27200640,
#  27200650,
#  27200660,
#  27230510,
#  27230526,
#  27230550,
#  27230560,
#  27230570,
#  27230610,
#  27230620,
#  27230630,
#  27230631,
#  27230645,
#  27230671,
#  27230672,
#  27230680,
#  27230695,
#  27230715,
#  27230725,
#  27230735,
#  27230745,
#  27230750,
#  27230770,
#  27230780,
#  27230790,
#  27230800,
#  27260510,
#  27260520,
#  27260530,
#  27260540,
#  27260550,
#  27260560,
#  27260561,
#  27260570,
#  27260580,
#  27260590,
#  27260601,
#  27260602,
#  27260610,
#  27260620,
#  27260630,
#  27260640,
#  27260651,
#  27260652,
#  27260661,
#  27260662,
#  27260670,
#  27260680,
#  27260690,
#  27290515,
#  27290535,
#  27290550,
#  27290555,
#  27290563,
#  27290568,
#  27290571,
#  27290572,
#  27290576,
#  27290577,
#  27290585,
#  27290590,
#  27290601,
#  27290602,
#  27290615,
#  27290624,
#  27290625,
#  27290626,
#  27290628,
#  27290630,
#  27290640,
#  27290650,
#  27710250,
#  27710253,
#  27710256,
#  27710259,
#  27710262,
#  27710265,
#  27710310,
#  27710330,
#  27710380]

# %% [markdown]
# 서울 행정구역 425개, 대구 행정구역 139개 \
# 서울은 코드번호가 11로 시작, 대구는 27로 시작하는 것을 알 수 있다

# %% [markdown]
# 9. COVID_Data2 - fpopl

# %%
fpopl
# Out:
#           base_ymd  tmzon_se_code sexdstn_se_code agrde_se_code  adstrd_code  \
# 0         20200101              0               M        age_00     11650560
# 1         20200101              0               M        age_00     11590620
# 2         20200101              0               M        age_00     11560710
# 3         20200101              0               M        age_00     11470680
# 4         20200101              0               M        age_00     11350665
# ...            ...            ...             ...           ...          ...
# 47546438  20200616             23               F        age_70     11500593
# 47546439  20200616             23               M        age_70     11350624
# 47546440  20200616             23               M        age_70     11305534
# 47546441  20200616             23               F        age_70     11500604
# 47546442  20200616             23               F        age_70     11320514
#
#           popltn_cascnt
# 0                    15
# 1                     6
# 2                     4
# 3                    12
# 4                     6
# ...                 ...
# 47546438             38
# 47546439             28
# 47546440             47
# 47546441             50
# 47546442             63
#
# [47546443 rows x 6 columns]

# %%
fpopl[fpopl['adstrd_code'].isin(seoul.adstrd_code.tolist())]
# Out:
#           base_ymd  tmzon_se_code sexdstn_se_code agrde_se_code  adstrd_code  \
# 0         20200101              0               M        age_00     11650560
# 1         20200101              0               M        age_00     11590620
# 2         20200101              0               M        age_00     11560710
# 3         20200101              0               M        age_00     11470680
# 4         20200101              0               M        age_00     11350665
# ...            ...            ...             ...           ...          ...
# 47546438  20200616             23               F        age_70     11500593
# 47546439  20200616             23               M        age_70     11350624
# 47546440  20200616             23               M        age_70     11305534
# 47546441  20200616             23               F        age_70     11500604
# 47546442  20200616             23               F        age_70     11320514
#
#           popltn_cascnt
# 0                    15
# 1                     6
# 2                     4
# 3                    12
# 4                     6
# ...                 ...
# 47546438             38
# 47546439             28
# 47546440             47
# 47546441             50
# 47546442             63
#
# [47546443 rows x 6 columns]

# %%
fpopl[fpopl['adstrd_code'].isin(daegu.adstrd_code.tolist())]
# Out:
# Empty DataFrame
# Columns: [base_ymd, tmzon_se_code, sexdstn_se_code, agrde_se_code, adstrd_code, popltn_cascnt]
# Index: []

# %% [markdown]
# 유동인구 데이터의 행정동 코드를 비교해보아, 서울만 유동인구 데이터 대상인 걸 알 수 있다.\
# 날짜별 인구 이동 시각화 자료를 만들어보자. (지역 코드와 날짜 기준)

# %% [markdown]
# 10. COVID_Data2 - card

# %%
card
# Out:
#          receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 0            20200104   1174066000      성내3동                  7041
# 1            20200104   1174066000      성내3동                  7022
# 2            20200104   1174066000      성내3동                  7021
# 3            20200104   1174066000      성내3동                  7020
# 4            20200104   1174066000      성내3동                  6110
# ...               ...          ...       ...                   ...
# 3713947      20200614   1121586000      구의2동                  4004
# 3713948      20200614   1121584700      자양4동                  9010
# 3713949      20200614   1162052500      보라매동                  6140
# 3713950      20200614   1135056000      월계1동                  9998
# 3713951      20200614   1159060500       흑석동                  9204
#
#         mrhst_induty_cl_nm  selng_cascnt   salamt
# 0                       약국           463  5843230
# 1                     치과의원            33  7835550
# 2                      한의원            53  4589800
# 3                       의원           339  9267240
# 4                    자동차정비            19  4441000
# ...                    ...           ...      ...
# 3713947              대형할인점           136  1195640
# 3713948              인테 리어             2    13100
# 3713949              주 차 장             2    14500
# 3713950              기타전문점             1    38000
# 3713951           사무통신기기수리             1    20000
#
# [3713952 rows x 7 columns]

# %%
card['adstrd_7digit'] = (card['adstrd_code']/100).astype(int)
card
# Out:
#          receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 0            20200104   1174066000      성내3동                  7041
# 1            20200104   1174066000      성내3동                  7022
# 2            20200104   1174066000      성내3동                  7021
# 3            20200104   1174066000      성내3동                  7020
# 4            20200104   1174066000      성내3동                  6110
# ...               ...          ...       ...                   ...
# 3777642      20200614   1121586000      구의2동                  4004
# 3777643      20200614   1121584700      자양4동                  9010
# 3777644      20200614   1162052500      보라매동                  6140
# 3777645      20200614   1135056000      월계1동                  9998
# 3777646      20200614   1159060500       흑석동                  9204
#
#         mrhst_induty_cl_nm selng_cascnt   salamt  adstrd_7digit
# 0                       약국          463  5843230       11740660
# 1                     치과의원           33  7835550       11740660
# 2                      한의원           53  4589800       11740660
# 3                       의원          339  9267240       11740660
# 4                    자동차정비           19  4441000       11740660
# ...                    ...          ...      ...            ...
# 3777642              대형할인점          136  1195640       11215860
# 3777643              인테 리어            2    13100       11215847
# 3777644              주 차 장            2    14500       11620525
# 3777645              기타전문점            1    38000       11350560
# 3777646           사무통신기기수리            1    20000       11590605
#
# [3777647 rows x 8 columns]

# %%
card[card['adstrd_7digit'].isin(seoul.adstrd_code.tolist())]
# Out:
#          receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 0            20200104   1174066000      성내3동                  7041
# 1            20200104   1174066000      성내3동                  7022
# 2            20200104   1174066000      성내3동                  7021
# 3            20200104   1174066000      성내3동                  7020
# 4            20200104   1174066000      성내3동                  6110
# ...               ...          ...       ...                   ...
# 3777642      20200614   1121586000      구의2동                  4004
# 3777643      20200614   1121584700      자양4동                  9010
# 3777644      20200614   1162052500      보라매동                  6140
# 3777645      20200614   1135056000      월계1동                  9998
# 3777646      20200614   1159060500       흑석동                  9204
#
#         mrhst_induty_cl_nm selng_cascnt   salamt  adstrd_7digit
# 0                       약국          463  5843230       11740660
# 1                     치과의원           33  7835550       11740660
# 2                      한의원           53  4589800       11740660
# 3                       의원          339  9267240       11740660
# 4                    자동차정비           19  4441000       11740660
# ...                    ...          ...      ...            ...
# 3777642              대형할인점          136  1195640       11215860
# 3777643              인테 리어            2    13100       11215847
# 3777644              주 차 장            2    14500       11620525
# 3777645              기타전문점            1    38000       11350560
# 3777646           사무통신기기수리            1    20000       11590605
#
# [3777647 rows x 8 columns]

# %% [markdown]
# fpopl 데이터와 마찬가지로 행정동 코드를 비교했을 때, 서울의 데이터만을 다루고 있음을 알 수 있다.

# %% [markdown]
# 11. COVID_Data2 - delivery

# %%
delivery
# Out:
#          SERIAL_NUMBER  PROCESS_DT DLVR_RQESTER_ID  DLVR_REQUST_STTUS_VALUE  \
# 0              4577985  2020-01-01         C000035                        1
# 1              4577986  2020-01-01         C000237                        1
# 2              4577988  2020-01-01         C000129                        1
# 3              4577989  2020-01-01         C000029                        1
# 4              4577991  2020-01-01         C000130                        1
# ...                ...         ...             ...                      ...
# 5158319       10672688  2020-06-21         C000312                        1
# 5158320       10672689  2020-06-21         C000026                        1
# 5158321       10672690  2020-06-21         C000130                        1
# 5158322       10672691  2020-06-21         C000237                        1
# 5158323       10672692  2020-06-21         C000209                        1
#
#         DLVR_RCEPT_CMPNY_ID DLVR_STORE_ID DLVR_STORE_INDUTY_NM  \
# 0                   C000035      S0032342                   치킨
# 1                   C000237      S0021847                   찜탕
# 2                   C000129      S0025740                   치킨
# 3                   C000043      S0039634                   한식
# 4                   C000130      S0002237                   한식
# ...                     ...           ...                  ...
# 5158319             C000312      S0029529                   야식
# 5158320             C000026      S0026242                   야식
# 5158321             C000130      S0042234                   야식
# 5158322             C000237      S0021766                족발/보쌈
# 5158323             C000209      S0022227                   야식
#
#          DLVR_STORE_LEGALDONG_CODE DLVR_STORE_SIDO DLVR_STORE_SIGUNGU  ...  \
# 0                       4812710600            경상남도          창원시 마산회원구  ...
# 1                       4121010200             경기도                광명시  ...
# 2                       1138010400           서울특별시                은평구  ...
# 3                       4115010100             경기도               의정부시  ...
# 4                       4128112800             경기도            고양시 덕양구  ...
# ...                            ...             ...                ...  ...
# 5158319                 4125010200             경기도               동두천시  ...
# 5158320                 1132010800           서울특별시                도봉구  ...
# 5158321                 4128112300             경기도            고양시 덕양구  ...
# 5158322                 4121010200             경기도                광명시  ...
# 5158323                 1154510300           서울특별시                금천구  ...
#
#         DLVR_MAN_ID DLVR_AMOUNT  CALL_RLAY_FEE_AMOUNT  GOODS_AMOUNT  \
# 0          D0005271        4290                   300         25000
# 1          D0003269        4800                   200         49000
# 2          D0001536        3300                   300         23000
# 3          D0005061        4500                   300         20000
# 4          D0005215        6500                   300         32000
# ...             ...         ...                   ...           ...
# 5158319    D0013004        3000                   500         26000
# 5158320    D0006251        3600                    55         22000
# 5158321    D0012754        3000                   300         17000
# 5158322    D0004485        3630                   200         53700
# 5158323    D0006541        4730                   300         46000
#
#          SETLE_KND_VALUE SETLE_CARD_CN      DLVR_RCEPT_TIME  \
# 0                      1      승인:비씨카드사  2020-01-01 00:15:49
# 1                      2           NaN  2020-01-01 01:12:14
# 2                      3           승인:  2020-01-01 00:01:14
# 3                      2           NaN  2020-01-01 01:01:34
# 4                      2           NaN  2020-01-01 01:05:06
# ...                  ...           ...                  ...
# 5158319                1       승인:하나카드  2020-06-21 22:48:22
# 5158320                2           NaN  2020-06-21 22:57:15
# 5158321                2           NaN  2020-06-21 22:55:08
# 5158322                1      승인:비씨카드사  2020-06-21 23:10:38
# 5158323                2           NaN  2020-06-21 23:04:50
#
#             DLVR_CARALC_TIME      DLVR_COMPT_TIME  DLVR_CANCL_TIME
# 0        2020-01-01 00:21:38  2020-01-01 00:41:37              NaN
# 1        2020-01-01 01:21:41  2020-01-01 01:31:44              NaN
# 2        2020-01-01 00:01:47  2020-01-01 00:18:47              NaN
# 3        2020-01-01 01:28:06  2020-01-01 01:36:48              NaN
# 4        2020-01-01 01:08:01  2020-01-01 01:29:00              NaN
# ...                      ...                  ...              ...
# 5158319  2020-06-21 22:48:37  2020-06-21 23:07:47              NaN
# 5158320  2020-06-21 22:58:00  2020-06-21 23:18:20              NaN
# 5158321  2020-06-21 22:55:22  2020-06-21 23:14:45              NaN
# 5158322  2020-06-21 23:11:03  2020-06-21 23:25:10              NaN
# 5158323  2020-06-21 23:14:35  2020-06-21 23:28:22              NaN
#
# [5158324 rows x 31 columns]

# %%
delivery.DLVR_STORE_SIDO.value_counts()
# Out:
# 경기도        3059586
# 서울특별시       791041
# 경상남도        266996
# 경상북도        261268
# 충청남도        168835
# 전라북도        124421
# 인천광역시       105697
# 충청북도         94685
# 제주특별자치도      67578
# 대전광역시        65325
# 대구광역시        63526
# 전라남도         34143
# 부산광역시        31279
# 강원도          12703
# 광주광역시        11241
# Name: DLVR_STORE_SIDO, dtype: int64

# %%
deli_sd = delivery[(delivery['DLVR_STORE_SIDO']=='대구광역시') | (delivery['DLVR_STORE_SIDO']=='서울특별시')]
deli_sd
# Out:
#          SERIAL_NUMBER  PROCESS_DT DLVR_RQESTER_ID  DLVR_REQUST_STTUS_VALUE  \
# 2              4577988  2020-01-01         C000129                        1
# 6              4577994  2020-01-01         C000049                        1
# 8              4577996  2020-01-01         C000104                        1
# 14             4578003  2020-01-01         C000010                        1
# 24             4578014  2020-01-01         C000101                        1
# ...                ...         ...             ...                      ...
# 5158279       10672642  2020-06-21         C000049                        1
# 5158298       10672664  2020-06-21         C000209                        1
# 5158308       10672675  2020-06-21         C000032                        1
# 5158320       10672689  2020-06-21         C000026                        1
# 5158323       10672692  2020-06-21         C000209                        1
#
#         DLVR_RCEPT_CMPNY_ID DLVR_STORE_ID DLVR_STORE_INDUTY_NM  \
# 2                   C000129      S0025740                   치킨
# 6                   C000049      S0022461                   분식
# 8                   C000101      S0021988                   치킨
# 14                  C000010      S0000458                   치킨
# 24                  C000104      S0021942                   치킨
# ...                     ...           ...                  ...
# 5158279             C000237      S0022444                   한식
# 5158298             C000210      S0019627               배달전문업체
# 5158308             C000447      S0000583                   한식
# 5158320             C000026      S0026242                   야식
# 5158323             C000209      S0022227                   야식
#
#          DLVR_STORE_LEGALDONG_CODE DLVR_STORE_SIDO DLVR_STORE_SIGUNGU  ...  \
# 2                       1138010400           서울특별시                은평구  ...
# 6                       1153010800           서울특별시                구로구  ...
# 8                       1156013300           서울특별시               영등포구  ...
# 14                      2726011100           대구광역시                수성구  ...
# 24                      1156013200           서울특별시               영등포구  ...
# ...                            ...             ...                ...  ...
# 5158279                 1153010600           서울특별시                구로구  ...
# 5158298                 1154510200           서울특별시                금천구  ...
# 5158308                 2771025628           대구광역시                달성군  ...
# 5158320                 1132010800           서울특별시                도봉구  ...
# 5158323                 1154510300           서울특별시                금천구  ...
#
#         DLVR_MAN_ID DLVR_AMOUNT  CALL_RLAY_FEE_AMOUNT  GOODS_AMOUNT  \
# 2          D0001536        3300                   300         23000
# 6          D0004461        3800                   300         28000
# 8          D0006259        4800                   200         17000
# 14         D0006876        3000                   300         18000
# 24         D0006407        3900                   300         19000
# ...             ...         ...                   ...           ...
# 5158279    D0004261        3300                   300         18900
# 5158298    D0006912        3300                   200         21900
# 5158308    D0011951        3000                   300         26500
# 5158320    D0006251        3600                    55         22000
# 5158323    D0006541        4730                   300         46000
#
#          SETLE_KND_VALUE SETLE_CARD_CN      DLVR_RCEPT_TIME  \
# 2                      3           승인:  2020-01-01 00:01:14
# 6                      2           NaN  2020-01-01 01:27:00
# 8                      1     승인:KB국민카드  2020-01-01 00:51:49
# 14                     1      승인:롯데카드사  2020-01-01 00:07:10
# 24                     2           NaN  2020-01-01 00:02:53
# ...                  ...           ...                  ...
# 5158279                2           NaN  2020-06-21 23:04:02
# 5158298                2           NaN  2020-06-21 23:37:27
# 5158308                2           NaN  2020-06-21 23:01:54
# 5158320                2           NaN  2020-06-21 22:57:15
# 5158323                2           NaN  2020-06-21 23:04:50
#
#             DLVR_CARALC_TIME      DLVR_COMPT_TIME  DLVR_CANCL_TIME
# 2        2020-01-01 00:01:47  2020-01-01 00:18:47              NaN
# 6        2020-01-01 01:27:47  2020-01-01 01:41:45              NaN
# 8        2020-01-01 00:52:12  2020-01-01 01:23:41              NaN
# 14       2020-01-01 00:07:25  2020-01-01 00:24:14              NaN
# 24       2020-01-01 00:16:01  2020-01-01 00:42:53              NaN
# ...                      ...                  ...              ...
# 5158279  2020-06-21 23:08:38  2020-06-21 23:18:13              NaN
# 5158298  2020-06-21 23:38:01  2020-06-21 23:48:26              NaN
# 5158308  2020-06-21 23:02:20  2020-06-21 23:05:10              NaN
# 5158320  2020-06-21 22:58:00  2020-06-21 23:18:20              NaN
# 5158323  2020-06-21 23:14:35  2020-06-21 23:28:22              NaN
#
# [854567 rows x 31 columns]

# %%
# date에서 month만 추출
def grap_month(data):
    data = str(data)
    return str(data[6:7])+'월'

deli_sd['month'] = deli_sd['PROCESS_DT'].apply(lambda x: grap_month(x))
deli_sd
# Out:
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          SERIAL_NUMBER  PROCESS_DT DLVR_RQESTER_ID  DLVR_REQUST_STTUS_VALUE  \
# 2              4577988  2020-01-01         C000129                        1
# 6              4577994  2020-01-01         C000049                        1
# 8              4577996  2020-01-01         C000104                        1
# 14             4578003  2020-01-01         C000010                        1
# 24             4578014  2020-01-01         C000101                        1
# ...                ...         ...             ...                      ...
# 5158279       10672642  2020-06-21         C000049                        1
# 5158298       10672664  2020-06-21         C000209                        1
# 5158308       10672675  2020-06-21         C000032                        1
# 5158320       10672689  2020-06-21         C000026                        1
# 5158323       10672692  2020-06-21         C000209                        1
#
#         DLVR_RCEPT_CMPNY_ID DLVR_STORE_ID DLVR_STORE_INDUTY_NM  \
# 2                   C000129      S0025740                   치킨
# 6                   C000049      S0022461                   분식
# 8                   C000101      S0021988                   치킨
# 14                  C000010      S0000458                   치킨
# 24                  C000104      S0021942                   치킨
# ...                     ...           ...                  ...
# 5158279             C000237      S0022444                   한식
# 5158298             C000210      S0019627               배달전문업체
# 5158308             C000447      S0000583                   한식
# 5158320             C000026      S0026242                   야식
# 5158323             C000209      S0022227                   야식
#
#          DLVR_STORE_LEGALDONG_CODE DLVR_STORE_SIDO DLVR_STORE_SIGUNGU  ...  \
# 2                       1138010400           서울특별시                은평구  ...
# 6                       1153010800           서울특별시                구로구  ...
# 8                       1156013300           서울특별시               영등포구  ...
# 14                      2726011100           대구광역시                수성구  ...
# 24                      1156013200           서울특별시               영등포구  ...
# ...                            ...             ...                ...  ...
# 5158279                 1153010600           서울특별시                구로구  ...
# 5158298                 1154510200           서울특별시                금천구  ...
# 5158308                 2771025628           대구광역시                달성군  ...
# 5158320                 1132010800           서울특별시                도봉구  ...
# 5158323                 1154510300           서울특별시                금천구  ...
#
#         DLVR_AMOUNT CALL_RLAY_FEE_AMOUNT  GOODS_AMOUNT  SETLE_KND_VALUE  \
# 2              3300                  300         23000                3
# 6              3800                  300         28000                2
# 8              4800                  200         17000                1
# 14             3000                  300         18000                1
# 24             3900                  300         19000                2
# ...             ...                  ...           ...              ...
# 5158279        3300                  300         18900                2
# 5158298        3300                  200         21900                2
# 5158308        3000                  300         26500                2
# 5158320        3600                   55         22000                2
# 5158323        4730                  300         46000                2
#
#          SETLE_CARD_CN      DLVR_RCEPT_TIME     DLVR_CARALC_TIME  \
# 2                  승인:  2020-01-01 00:01:14  2020-01-01 00:01:47
# 6                  NaN  2020-01-01 01:27:00  2020-01-01 01:27:47
# 8            승인:KB국민카드  2020-01-01 00:51:49  2020-01-01 00:52:12
# 14            승인:롯데카드사  2020-01-01 00:07:10  2020-01-01 00:07:25
# 24                 NaN  2020-01-01 00:02:53  2020-01-01 00:16:01
# ...                ...                  ...                  ...
# 5158279            NaN  2020-06-21 23:04:02  2020-06-21 23:08:38
# 5158298            NaN  2020-06-21 23:37:27  2020-06-21 23:38:01
# 5158308            NaN  2020-06-21 23:01:54  2020-06-21 23:02:20
# 5158320            NaN  2020-06-21 22:57:15  2020-06-21 22:58:00
# 5158323            NaN  2020-06-21 23:04:50  2020-06-21 23:14:35
#
#              DLVR_COMPT_TIME DLVR_CANCL_TIME  month
# 2        2020-01-01 00:18:47             NaN     1월
# 6        2020-01-01 01:41:45             NaN     1월
# 8        2020-01-01 01:23:41             NaN     1월
# 14       2020-01-01 00:24:14             NaN     1월
# 24       2020-01-01 00:42:53             NaN     1월
# ...                      ...             ...    ...
# 5158279  2020-06-21 23:18:13             NaN     6월
# 5158298  2020-06-21 23:48:26             NaN     6월
# 5158308  2020-06-21 23:05:10             NaN     6월
# 5158320  2020-06-21 23:18:20             NaN     6월
# 5158323  2020-06-21 23:28:22             NaN     6월
#
# [854567 rows x 32 columns]

# %%
deli_sd['counts'] = 1
deli_sd
# Out:
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#          SERIAL_NUMBER  PROCESS_DT DLVR_RQESTER_ID  DLVR_REQUST_STTUS_VALUE  \
# 2              4577988  2020-01-01         C000129                        1
# 6              4577994  2020-01-01         C000049                        1
# 8              4577996  2020-01-01         C000104                        1
# 14             4578003  2020-01-01         C000010                        1
# 24             4578014  2020-01-01         C000101                        1
# ...                ...         ...             ...                      ...
# 5158279       10672642  2020-06-21         C000049                        1
# 5158298       10672664  2020-06-21         C000209                        1
# 5158308       10672675  2020-06-21         C000032                        1
# 5158320       10672689  2020-06-21         C000026                        1
# 5158323       10672692  2020-06-21         C000209                        1
#
#         DLVR_RCEPT_CMPNY_ID DLVR_STORE_ID DLVR_STORE_INDUTY_NM  \
# 2                   C000129      S0025740                   치킨
# 6                   C000049      S0022461                   분식
# 8                   C000101      S0021988                   치킨
# 14                  C000010      S0000458                   치킨
# 24                  C000104      S0021942                   치킨
# ...                     ...           ...                  ...
# 5158279             C000237      S0022444                   한식
# 5158298             C000210      S0019627               배달전문업체
# 5158308             C000447      S0000583                   한식
# 5158320             C000026      S0026242                   야식
# 5158323             C000209      S0022227                   야식
#
#          DLVR_STORE_LEGALDONG_CODE DLVR_STORE_SIDO DLVR_STORE_SIGUNGU  ...  \
# 2                       1138010400           서울특별시                은평구  ...
# 6                       1153010800           서울특별시                구로구  ...
# 8                       1156013300           서울특별시               영등포구  ...
# 14                      2726011100           대구광역시                수성구  ...
# 24                      1156013200           서울특별시               영등포구  ...
# ...                            ...             ...                ...  ...
# 5158279                 1153010600           서울특별시                구로구  ...
# 5158298                 1154510200           서울특별시                금천구  ...
# 5158308                 2771025628           대구광역시                달성군  ...
# 5158320                 1132010800           서울특별시                도봉구  ...
# 5158323                 1154510300           서울특별시                금천구  ...
#
#         CALL_RLAY_FEE_AMOUNT GOODS_AMOUNT  SETLE_KND_VALUE  SETLE_CARD_CN  \
# 2                        300        23000                3            승인:
# 6                        300        28000                2            NaN
# 8                        200        17000                1      승인:KB국민카드
# 14                       300        18000                1       승인:롯데카드사
# 24                       300        19000                2            NaN
# ...                      ...          ...              ...            ...
# 5158279                  300        18900                2            NaN
# 5158298                  200        21900                2            NaN
# 5158308                  300        26500                2            NaN
# 5158320                   55        22000                2            NaN
# 5158323                  300        46000                2            NaN
#
#              DLVR_RCEPT_TIME     DLVR_CARALC_TIME      DLVR_COMPT_TIME  \
# 2        2020-01-01 00:01:14  2020-01-01 00:01:47  2020-01-01 00:18:47
# 6        2020-01-01 01:27:00  2020-01-01 01:27:47  2020-01-01 01:41:45
# 8        2020-01-01 00:51:49  2020-01-01 00:52:12  2020-01-01 01:23:41
# 14       2020-01-01 00:07:10  2020-01-01 00:07:25  2020-01-01 00:24:14
# 24       2020-01-01 00:02:53  2020-01-01 00:16:01  2020-01-01 00:42:53
# ...                      ...                  ...                  ...
# 5158279  2020-06-21 23:04:02  2020-06-21 23:08:38  2020-06-21 23:18:13
# 5158298  2020-06-21 23:37:27  2020-06-21 23:38:01  2020-06-21 23:48:26
# 5158308  2020-06-21 23:01:54  2020-06-21 23:02:20  2020-06-21 23:05:10
# 5158320  2020-06-21 22:57:15  2020-06-21 22:58:00  2020-06-21 23:18:20
# 5158323  2020-06-21 23:04:50  2020-06-21 23:14:35  2020-06-21 23:28:22
#
#         DLVR_CANCL_TIME month  counts
# 2                   NaN    1월       1
# 6                   NaN    1월       1
# 8                   NaN    1월       1
# 14                  NaN    1월       1
# 24                  NaN    1월       1
# ...                 ...   ...     ...
# 5158279             NaN    6월       1
# 5158298             NaN    6월       1
# 5158308             NaN    6월       1
# 5158320             NaN    6월       1
# 5158323             NaN    6월       1
#
# [854567 rows x 33 columns]

# %%
deli_gr = deli_sd.groupby(['DLVR_STORE_SIDO','month'])[['GOODS_AMOUNT','counts']].sum().reset_index(drop = False)
plt.figure(figsize = (20,10))
sns.barplot(data = deli_gr, x ='month', y ='counts', hue='DLVR_STORE_SIDO', palette="deep")
plt.show()
# Out:
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 44305 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 50669 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 50872 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 53945 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 44305 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 50669 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 50872 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 53945 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/sundooedu/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# 12. COVID_Data2 - index

# %%
index
# Out:
#         period     catl    catm  age gender sido sigungu         cgi
# 0       201901  건강/의료용품  건강관리용품   20      F   서울     관악구  115.374642
# 1       201901  건강/의료용품  건강관리용품   20      F   서울     광진구  119.596454
# 2       201901  건강/의료용품  건강관리용품   20      F   서울     도봉구  156.992847
# 3       201901  건강/의료용품  건강관리용품   20      F   서울     동작구   58.342726
# 4       201901  건강/의료용품  건강관리용품   20      F   서울     마포구  145.147595
# ...        ...      ...     ...  ...    ...  ...     ...         ...
# 127520  202005      화장품     화장품  all    all   서울     강서구   51.365660
# 127521  202005      화장품     화장품  all    all   서울     관악구   61.997865
# 127522  202005      화장품     화장품  all    all   서울     금천구   82.198402
# 127523  202005      화장품     화장품  all    all   서울     도봉구   35.875600
# 127524  202005      화장품     화장품  all    all   서울     용산구   45.569377
#
# [127525 rows x 8 columns]
